# %% [markdown]
# <a href="https://colab.research.google.com/github/LhsEric/dscareer_dsml_exercies_coach/blob/main/Task_08_%E4%BD%9C%E6%A5%AD_03%E3%80%90%E5%AF%A6%E4%BD%9C%E9%A1%8C%E3%80%91%E6%A9%9F%E5%99%A8%E5%AD%B8%E7%BF%92_%E5%88%86%E7%BE%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Task #08 作業 03【實作題】機器學習 - 分群

# %% [markdown]
# 練習：請根據給定的資料集，利用 K-means 進行分群，請比較看看 k = 3、4、5 哪一種可能比較好？為什麼？

# %% [markdown]
# K-Means 聚類是一種常用的非監督式學習算法，用於將資料分為 k 個不同的群體。在 scikit-learn 中，可以使用 KMeans 類進行 K-Means 聚類：

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans

X = np.array([[1, 2], [1, 4], [1, 0], [4, 2], [4, 4], [4, 0]])
print('===== 原始資料 =====')

df = pd.DataFrame(X)
print(df)

c3_model = KMeans(n_clusters = 3)
c3_model.fit(df)
y_c3_pred = c3_model.predict(df)
print("n_clusters = 3:",y_c3_pred)

c4_model = KMeans(n_clusters = 4)
c4_model.fit(df)
y_c4_pred = c4_model.predict(df)
print("n_clusters = 4:",y_c4_pred)

c5_model = KMeans(n_clusters = 4)
c5_model.fit(df)
y_c5_pred = c5_model.predict(df)
print("n_clusters = 5:",y_c5_pred)
# Out:
# ===== 原始資料 =====
#    0  1
# 0  1  2
# 1  1  4
# 2  1  0
# 3  4  2
# 4  4  4
# 5  4  0
# n_clusters = 3: [2 1 2 0 1 0]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# n_clusters = 4: [1 2 1 0 0 3]
# n_clusters = 5: [1 3 1 0 0 2]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# 原始資料
X = np.array([[1, 2], [1, 4], [1, 0], [4, 2], [4, 4], [4, 0]])
print('===== 原始資料 =====')

df = pd.DataFrame(X, columns=['x', 'y'])
print(df)

# KMeans 聚類
def plot_kmeans(n, df):
    kmeans_model = KMeans(n_clusters=n)
    kmeans_model.fit(df)
    y_pred = kmeans_model.predict(df)

    # 繪製結果
    plt.scatter(df['x'], df['y'], c=y_pred, s=50, cmap='viridis')

    # 繪製聚類中心
    centers = kmeans_model.cluster_centers_
    plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75)

    plt.title(f'KMeans with {n} clusters')
    plt.show()

    return y_pred

# n_clusters = 3
y_c3_pred = plot_kmeans(3, df)
print("n_clusters = 3:", y_c3_pred)

# n_clusters = 4
y_c4_pred = plot_kmeans(4, df)
print("n_clusters = 4:", y_c4_pred)

# n_clusters = 5
y_c5_pred = plot_kmeans(5, df)
print("n_clusters = 5:", y_c5_pred)
# Out:
# ===== 原始資料 =====
#    x  y
# 0  1  2
# 1  1  4
# 2  1  0
# 3  4  2
# 4  4  4
# 5  4  0
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# n_clusters = 3: [1 0 1 2 0 2]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# n_clusters = 4: [0 2 0 3 1 3]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# n_clusters = 5: [3 3 1 2 0 4]
